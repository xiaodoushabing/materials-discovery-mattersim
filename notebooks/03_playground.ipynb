# %%
import torch
import time
import numpy as np
import rdkit

from ase import Atoms
from ase.visualize import view
from ase.build import bulk
from ase.units import GPa
from ase.spacegroup import crystal

from mattersim.applications.batch_relax import BatchRelaxer
from mattersim.forcefield.potential import Potential
from mattersim.datasets.utils.build import build_dataloader
from mattersim.forcefield.potential import MatterSimCalculator
from mattersim.applications.relax import Relaxer

from utils.visualisation import plot_potential, plot_relaxation, visualise_structure

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"MatterSim running on {device}")
# Out:
# MatterSim running on cuda

# %%
model = 5

# %%
# Define the L1₀ unit cell parameters
a = 3.85  # Lattice constant in x and y
c = 3.72  # Lattice constant in z (slightly compressed)
alpha, beta, gamma = 90, 90, 90

# Define the L1₀ structure using ASE
structure = crystal(
    symbols=['Fe', 'Pt'],
    basis=[[0, 0, 0], [0.5, 0.5, 0.5]],  # Atomic positions as fractional coordinates
    spacegroup=123,  # P4/mmm
    cellpar=[a, a, c, alpha, beta, gamma]  # a, b, c, alpha, beta, gamma
)

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[0.    0.    0.   ]
#  [1.925 1.925 1.86 ]]
# <div id="3dmolviewer_17386454366783218"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17386454366783218" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17386454366783218 = null;
# var warn = document.getElementById("3dmolwarning_17386454366783218");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17386454366783218 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17386454366783218"),{backgroundColor:"white"});
# viewer_17386454366783218.zoomTo();
# 	viewer_17386454366783218.addModel("54\nLattice=\"11.55 0.0 0.0 0.0 11.55 0.0 0.0 0.0 11.16\" Properties=species:S:1:pos:R:3:spacegroup_kinds:I:1 spacegroup=\"P 4/m m m\" unit_cell=conventional pbc=\"T T T\"\nFe       0.00000000       0.00000000       0.00000000        0\nPt       1.92500000       1.92500000       1.86000000        1\nFe       0.00000000       0.00000000       3.72000000        0\nPt       1.92500000       1.92500000       5.58000000        1\nFe       0.00000000       0.00000000       7.44000000        0\nPt       1.92500000       1.92500000       9.30000000        1\nFe       0.00000000       3.85000000       0.00000000        0\nPt       1.92500000       5.77500000       1.86000000        1\nFe       0.00000000       3.85000000       3.72000000        0\nPt       1.92500000       5.77500000       5.58000000        1\nFe       0.00000000       3.85000000       7.44000000        0\nPt       1.92500000       5.77500000       9.30000000        1\nFe       0.00000000       7.70000000       0.00000000        0\nPt       1.92500000       9.62500000       1.86000000        1\nFe       0.00000000       7.70000000       3.72000000        0\nPt       1.92500000       9.62500000       5.58000000        1\nFe       0.00000000       7.70000000       7.44000000        0\nPt       1.92500000       9.62500000       9.30000000        1\nFe       3.85000000       0.00000000       0.00000000        0\nPt       5.77500000       1.92500000       1.86000000        1\nFe       3.85000000       0.00000000       3.72000000        0\nPt       5.77500000       1.92500000       5.58000000        1\nFe       3.85000000       0.00000000       7.44000000        0\nPt       5.77500000       1.92500000       9.30000000        1\nFe       3.85000000       3.85000000       0.00000000        0\nPt       5.77500000       5.77500000       1.86000000        1\nFe       3.85000000       3.85000000       3.72000000        0\nPt       5.77500000       5.77500000       5.58000000        1\nFe       3.
# 	viewer_17386454366783218.addLine({"start": {"x": 3.85, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 3.85, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 0.0}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_17386454366783218.addLine({"st

# %%
structure.calc = MatterSimCalculator(load_path=f"MatterSim-v1.0.0-{model}M.pth", device=device)
# Out:
# 2025-02-04 05:03:56.685 | INFO     | mattersim.forcefield.potential:from_checkpoint:891 - Loading the pre-trained mattersim-v1.0.0-5M.pth model
# 2025-02-04 05:03:57.652 | INFO     | mattersim.forcefield.potential:from_checkpoint:891 - Loading the pre-trained mattersim-v1.0.0-5M.pth model
# /usr/local/lib/python3.12/dist-packages/mattersim/forcefield/potential.py:896: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(load_path, map_location=device)

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -10.912311553955078
# Energy per atom (eV/atom)   = -5.456155776977539
# Forces of first atom (eV/A) = [ 1.0877848e-06  9.3877316e-07 -1.2814999e-06]
# Stress[0][0] (x-x) (eV/A^3) = 0.1328575326803123
# Stress[0][0] (x-x) (GPa)    = 21.286123275756832

# %%
# initialize the relaxation object
relaxer = Relaxer(
    optimizer="BFGS", # the optimization method
    filter = "FrechetCellFilter",
    # filter="ExpCellFilter"
    # filter = None, # filter to apply to the cell
# 	viewer_17386454376236863.addLine({"start": {"x": 2.748458325180891e-34, "y": 3.240309815230458, "z": 1.1552727642540656e-17}, "end": {"x": 6.843284064931989e-32, "y": 3.240309815230458, "z": 2.7509930733037997}, "color": "black"});
# 	viewer_17386454376236863.addLine({"start": {"x": 6.81579948168018e-32, "y": 1.0344603085468796e-17, "z": 2.7509930733037997}, "end": {"x": 3.240309815230458, "y": 1.0344603085468796e-17, "z": 2.7509930733037997}, "color": "black"});
# 	viewer_17386454376236863.addLine({"start": {"x": 6.81579948168018e-32, "y": 1.0344603085468796e-17, "z": 2.7509930733037997}, "end": {"x": 6.843284064931989e-32, "y": 3.240309815230458, "z": 2.7509930733037997}, "color": "black"});
# 	viewer_17386454376236863.addLine({"start": {"x": 3.240309815230458, "y": 3.240309815230458, "z": 1.155272764253968e-17}, "end": {"x": 3.240309815230458, "y": 3.240309815230458, "z": 2.7509930733037997}, "color": "black"});
# 	viewer_17386454376236863.addLine({"start": {"x": 3.240309815230458, "y": 1.0344603085468796e-17, "z": 2.7509930733037997}, "end": {"x": 3.240309815230458, "y": 3.240309815230458, "z": 2.7509930733037997}, "color": "black"});
# 	viewer_17386454376236863.addLine({"start": {"x": 6.843284064931989e-32, "y": 3.2403098152304

# %%
# Define the L1₀ unit cell parameters
a = 3.85  # Lattice constant in x and y
c = 3.72  # Lattice constant in z (slightly compressed)

# Define the atomic positions and symbols
positions = [
    (0, 0, 0),               # Fe atom
    (0.5 * a, 0.5 * a, 0.5 * c),  # Pt atom
]

symbols = ['Fe', 'Pt']

# Create the unit cell for L1₀ FePt
structure = Atoms(symbols="FePt",
                 positions=positions,
                 cell=[(a, 0, 0), (0, a, 0), (0, 0, c)],
                 pbc=True)  # Periodic boundary conditions

structure.rattle(stdev=0.01)

# %%
# # Define the L1₀ unit cell parameters
# a = 3.85  # Lattice constant in x and y
# c = 3.72  # Lattice constant in z (slightly compressed)
# alpha, beta, gamma = 90, 90, 90


# # Define the L1₀ structure using spacegroup
# structure = crystal(
#     symbols=['Fe', 'Pt'],
#     basis=[[0, 0, 0], [0.5, 0.5, 0.5]],  # Atomic positions as fractional coordinates
#     spacegroup=123,  # P4/mmm
#     cellpar=[a, a, c, alpha, beta, gamma]  # a, b, c, alpha, beta, gamma
# )

# structure.rattle(stdev=0.01)

# %%
structure.get_scaled_positions()
# Out:
# array([[0.00129017, 0.99964087, 0.0017411 ],
#        [0.50395592, 0.49939181, 0.4993706 ]])

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[ 4.96714153e-03 -1.38264301e-03  6.47688538e-03]
#  [ 1.94023030e+00  1.92265847e+00  1.85765863e+00]]
# <div id="3dmolviewer_173864543764915"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_173864543764915" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_173864543764915 = null;
# var warn = document.getElementById("3dmolwarning_173864543764915");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer
# 	viewer_173864543764915.addLine({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0.0, "y": 3.85, "z": 0.0}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0.0, "y": 0.0, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 3.72}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 0.0}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 0.0, "z": 3.72}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 3.85, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_173864543764915.addLine({"start": {"x": 0.0, "y": 3.85, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "

# %%
structure.calc = MatterSimCalculator(load_path=f"MatterSim-v1.0.0-{model}M.pth", device=device)
# Out:
# /usr/local/lib/python3.12/dist-packages/mattersim/forcefield/potential.py:896: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(load_path, map_location=device)

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -10.912513732910156
# Energy per atom (eV/atom)   = -5.456256866455078
# Forces of first atom (eV/A) = [-0.02334106  0.0021806   0.0181929 ]
# Stress[0][0] (x-x) (eV/A^3) = 0.1328592945809292
# Stress[0][0] (x-x) (GPa)    = 21.286405563354492

# %%
# initialize the relaxation object
relaxer = Relaxer(
    optimizer="BFGS", # the optimization method
    filter = "FrechetCellfilter",
    # filter="ExpCellFilter", # filter to apply to the cell
    constrain_symmetry=True, # whether to constrain the symmetry
)

relaxed_structure = relaxer.relax(structure, fmax=0.001, steps=500)
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 05:03:57      -10.912512        3.663199
# BFGS:    1 05:03:57      -11.506921        4.003320
# BFGS:    2 05:03:57      -13.788439        3.171814
# BFGS:    3 05:03:57      -14.625860        0.190155
# BFGS:    4 05:03:57      -14.628172        0.196123
# BFGS:    5 05:03:57      -14.184110        2.640508
# BFGS:    6 05:03:57      -14.634958        0.221207
# BFGS:    7 05:03:57      -14.641796        0.308700
# BFGS:    8 05:03:57      -14.385566        2.259005
# BFGS:    9 05:03:57      -14.655932        0.493695
# BFGS:   10 05:03:57      -14.665010        0.618661
# BFGS:   11 05:03:57      -14.667042        0.805320
# BFGS:   12 05:03:57      -14.683666        0.695365
# BFGS:   13 05:03:58      -14.692745        0.599825
# BFGS:   14 05:03:58      -14.707539        0.337819
# BFGS:   15 05:03:58      -14.714073        0.093157
# BFGS:   16 05:03:58      -14.714493        0.040560
# BFGS:   17 05:03:58      -14.714563        0.037351
# BFGS:   18 05:03:58      -14.714665        0.028508
# BFGS:   19 05:03:58      -14.714787        0.025583
# BFGS:   20 05:03:58      -14.714849        0.016370
# BFGS:   21 05:03:58      -14.714867        0.011795
# BFGS:   22 05:03:58      -14.714874        0.013780
# BFGS:   23 05:03:58      -14.714899        0.028786
# BFGS:   24 05:03:58      -14.715258        0.181520
# BFGS:   25 05:03:58      -14.695305        1.322464
# BFGS:   26 05:03:58      -14.717490        0.167034
# BFGS:   27 05:03:58      -14.718998        0.299421
# BFGS:   28 05:03:58      -14.720054        0.449445
# BFGS:   29 05:03:58      -14.720810        0.535755
# BFGS:   30 05:03:58      -14.722188        1.030244
# BFGS:   31 05:03:58      -14.724922        0.847374
# BFGS:   32 05:03:58      -14.730925        0.812668
# BFGS:   33 05:03:58      -14.887589        0.759968
# BFGS:   34 05:03:58      -14.802536        2.178387
# BFGS:   35 05:03:59      -14.933062        0.541676
# BFGS:   36 05:03:59      -14.946716        0.387214
# BFGS:   37 05:03:59      -14.960376        0.074070
# BFGS:   38 05:03:59      -14.960770        0.076467
# BFGS:   39 05:03:59      -14.961596        0.087406
# BFGS:   40 05:03:59      -14.962013        0.087467
# BFGS:   41 05:03:59      -14.962687        0.054435
# BFGS:   42 05:03:59      -14.962857        0.020635
# BFGS:   43 05:03:59      -14.962885        0.003229
# BFGS:   44 05:03:59      -14.962887        0.001787
# BFGS:   45 05:03:59      -14.962886        0.001659
# BFGS:   46 05:03:59      -14.962887        0.001569
# BFGS:   47 05:03:59      -14.962887        0.001271
# BFGS:   48 05:03:59      -14.962888        0.000594

# %%
structure.get_positions()
# Out:
# array([[ 7.14647406e-03, -1.35004234e-03,  1.53371812e-03],
#        [ 1.38164908e+00,  1.87826131e+00,  1.37351683e+00]])

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -14.96288776397705
# Energy per atom (eV/atom)   = -7.481443881988525
# Forces of first atom (eV/A) = [ 3.5349838e-04 -2.8871000e-08 -7.5320480e-05]
# Stress[0][0] (x-x) (eV/A^3) = -6.1466283153366575e-06
# Stress[0][0] (x-x) (GPa)    = -0.0009847984183579683

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[ 7.14647406e-03 -1.35004234e-03  1.53371812e-03]
#  [ 1.38164908e+00  1.87826131e+00  1.37351683e+00]]
# <div id="3dmolviewer_1738645439290581"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_1738645439290581" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1738645439290581 = null;
# var warn = document.getElementById("3dmolwarning_1738645439290581");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1738645439290581 = $3Dmol.createViewer(document.getElementById("3dmolviewer_