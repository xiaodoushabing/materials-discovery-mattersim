# %%
import torch
import os
import sys
sys.path.append(os.path.abspath(".."))

from ase import Atoms
from ase.visualize import view
from ase.build import bulk
from ase.units import GPa
from ase.spacegroup import crystal

from mattersim.applications.batch_relax import BatchRelaxer
from mattersim.forcefield.potential import Potential
from mattersim.datasets.utils.build import build_dataloader
from mattersim.forcefield.potential import MatterSimCalculator
from mattersim.applications.relax import Relaxer

from utils.visualisation import plot_potential, plot_relaxation, visualise_structure

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"MatterSim running on {device}")
# Out:
# MatterSim running on cuda

# %%
model = 5

# %%
# Define the L1₀ unit cell parameters
a = 3.85  # Lattice constant in x and y
c = 3.72  # Lattice constant in z (slightly compressed)
alpha, beta, gamma = 90, 90, 90

# Define the L1₀ structure using ASE
structure = crystal(
    symbols=['Fe', 'Pt'],
    basis=[[0, 0, 0], [0.5, 0.5, 0.5]],  # Atomic positions as fractional coordinates
    spacegroup=123,  # P4/mmm
    cellpar=[a, a, c, alpha, beta, gamma]  # a, b, c, alpha, beta, gamma
)

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[0.    0.    0.   ]
#  [1.925 1.925 1.86 ]]
# <div id="3dmolviewer_17387380189917264"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17387380189917264" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17387380189917264 = null;
# var warn = document.getElementById("3dmolwarning_17387380189917264");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17387380189917264 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17387380189917264"),{backgroundColor:"white"});
# viewer_17387380189917264.zoomTo();
# 	viewer_17387380189917264.addModel("54\nLattice=\"11.55 0.0 0.0 0.0 11.55 0.0 0.0 0.0 11.16\" Properties=species:S:1:pos:R:3:spacegroup_kinds:I:1 spacegroup=\"P 4/m m m\" unit_cell=conventional pbc=\"T T T\"\nFe       0.00000000       0.00000000       0.00000000        0\nPt       1.92500000       1.92500000       1.86000000        1\nFe       0.00000000       0.00000000       3.72000000        0\nPt       1.92500000       1.92500000       5.58000000        1\nFe       0.00000000       0.00000000       7.44000000        0\nPt       1.92500000       1.92500000       9.30000000        1\nFe       0.00000000       3.85000000       0.00000000        0\nPt       1.92500000       5.77500000       1.86000000        1\nFe       0.00000000       3.85000000       3.72000000        0\nPt       1.92500000       5.77500000       5.58000000        1\nFe       0.00000000       3.85000000       7.44000000        0\nPt       1.92500000       5.77500000       9.30000000        1\nFe       0.00000000       7.70000000       0.00000000        0\nPt       1.92500000       9.62500000       1.86000000        1\nFe       0.00000000       7.70000000       3.72000000        0\nPt       1.92500000       9.62500000       5.58000000        1\nFe       0.00000000       7.70000000       7.44000000        0\nPt       1.92500000       9.62500000       9.30000000        1\nFe       3.85000000       0.00000000       0.00000000        0\nPt       5.77500000       1.92500000       1.86000000        1\nFe       3.85000000       0.00000000       3.72000000        0\nPt       5.77500000       1.92500000       5.58000000        1\nFe       3.85000000       0.00000000       7.44000000        0\nPt       5.77500000       1.92500000       9.30000000        1\nFe       3.85000000       3.85000000       0.00000000        0\nPt       5.77500000       5.77500000       1.86000000        1\nFe       3.85000000       3.85000000       3.72000000        0\nPt       5.77500000       5.77500000       5.58000000        1\nFe       3.85000000       3.85000000       7.44000000        0\n
# 	viewer_17387380189917264.addLine({"start": {"x": 3.85, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 3.85, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "black"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 0.0}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 3.85, "y": 0.0, "z": 0.0}, "end": {"x": 3.85, "y": 0.0, "z": 3.72}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 3.85, "y": 3.85, "z": 0.0}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"start": {"x": 0.0, "y": 3.85, "z": 0.0}, "end": {"x": 0.0, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_17387380189917264.addLine({"st

# %%
structure.calc = MatterSimCalculator(load_path=f"MatterSim-v1.0.0-{model}M.pth", device=device)
# Out:
# 2025-02-05 06:46:58.996 | INFO     | mattersim.forcefield.potential:from_checkpoint:891 - Loading the pre-trained mattersim-v1.0.0-5M.pth model
# 2025-02-05 06:46:59.971 | INFO     | mattersim.forcefield.potential:from_checkpoint:891 - Loading the pre-trained mattersim-v1.0.0-5M.pth model
# /usr/local/lib/python3.12/dist-packages/mattersim/forcefield/potential.py:896: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(load_path, map_location=device)

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -10.912311553955078
# Energy per atom (eV/atom)   = -5.456155776977539
# Forces of first atom (eV/A) = [ 9.7602606e-07  1.3038516e-06 -1.3113022e-06]
# Stress[0][0] (x-x) (eV/A^3) = 0.1328575922039818
# Stress[0][0] (x-x) (GPa)    = 21.2861328125

# %%
# initialize the relaxation object
relaxer = Relaxer(
    optimizer="BFGS", # the optimization method
    filter = "FrechetCellFilter",
    # filter="ExpCellFilter"
    # filter = None, # filter to apply to the cell
    constrain_symmetry=True, # whether to constrain the symmetry
)
pressure_in_GPa=0
relaxed_structure = relaxer.relax(structure, params_filter={"scalar_pressure": pressure_in_GPa}, steps=500)
# 	viewer_17387380199426818.addLine({"start": {"x": -2.8132912122456027e-31, "y": 2.4572233649269146e-17, "z": 2.750993355956847}, "end": {"x": 3.240310056248057, "y": 2.4572233649269146e-17, "z": 2.750993355956847}, "color": "black"});
# 	viewer_17387380199426818.addLine({"start": {"x": -2.8132912122456027e-31, "y": 2.4572233649269146e-17, "z": 2.750993355956847}, "end": {"x": -2.8142995551842058e-31, "y": 3.240310056248058, "z": 2.750993355956847}, "color": "black"});
# 	viewer_17387380199426818.addLine({"start": {"x": 3.240310056248057, "y": 3.240310056248058, "z": 2.4265861571691527e-17}, "end": {"x": 3.240310056248057, "y": 3.240310056248058, "z": 2.750993355956847}, "color": "black"});
# 	viewer_17387380199426818.addLine({"start": {"x": 3.240310056248057, "y": 2.4572233649269146e-17, "z": 2.750993355956847}, "end": {"x": 3.240310056248057, "y": 3.240310056248058, "z": 2.750993355956847}, "color": "black"});
# 	viewer_17387380199426818.addLine({"start": {"x": -2.8142995551842058e-31, "y": 3.

# %%
# Define the L1₀ unit cell parameters
a = 3.85  # Lattice constant in x and y
c = 3.72  # Lattice constant in z (slightly compressed)

# Define the atomic positions and symbols
positions = [
    (0, 0, 0),               # Fe atom
    (0.5 * a, 0.5 * a, 0.5 * c),  # Pt atom
]

symbols = ['Fe', 'Pt']

# Create the unit cell for L1₀ FePt
structure = Atoms(symbols="FePt",
                 positions=positions,
                 cell=[(a, 0, 0), (0, a, 0), (0, 0, c)],
                 pbc=True)  # Periodic boundary conditions

structure.rattle(stdev=0.01)

# %%
# # Define the L1₀ unit cell parameters
# a = 3.85  # Lattice constant in x and y
# c = 3.72  # Lattice constant in z (slightly compressed)
# alpha, beta, gamma = 90, 90, 90


# # Define the L1₀ structure using spacegroup
# structure = crystal(
#     symbols=['Fe', 'Pt'],
#     basis=[[0, 0, 0], [0.5, 0.5, 0.5]],  # Atomic positions as fractional coordinates
#     spacegroup=123,  # P4/mmm
#     cellpar=[a, a, c, alpha, beta, gamma]  # a, b, c, alpha, beta, gamma
# )

# structure.rattle(stdev=0.01)

# %%
structure.get_scaled_positions()
# Out:
# array([[0.00129017, 0.99964087, 0.0017411 ],
#        [0.50395592, 0.49939181, 0.4993706 ]])

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[ 4.96714153e-03 -1.38264301e-03  6.47688538e-03]
#  [ 1.94023030e+00  1.92265847e+00  1.85765863e+00]]
# <div id="3dmolviewer_173873801996778"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_173873801996778" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_173873801996778 = null;
# var warn = document.getElementById("3dmolwarning_173873801996778");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer
# 	viewer_173873801996778.addLine({"start": {"x": 3.85, "y": 0.0, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "z": 3.72}, "color": "grey"});
# 	viewer_173873801996778.addLine({"start": {"x": 0.0, "y": 3.85, "z": 3.72}, "end": {"x": 3.85, "y": 3.85, "

# %%
structure.calc = MatterSimCalculator(load_path=f"MatterSim-v1.0.0-{model}M.pth", device=device)
# Out:
# /usr/local/lib/python3.12/dist-packages/mattersim/forcefield/potential.py:896: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(load_path, map_location=device)

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -10.912513732910156
# Energy per atom (eV/atom)   = -5.456256866455078
# Forces of first atom (eV/A) = [-0.02334077  0.00218054  0.01819279]
# Stress[0][0] (x-x) (eV/A^3) = 0.1328593064856631
# Stress[0][0] (x-x) (GPa)    = 21.286407470703125

# %%
# initialize the relaxation object
relaxer = Relaxer(
    optimizer="BFGS", # the optimization method
    filter = "FrechetCellfilter",
    # filter="ExpCellFilter", # filter to apply to the cell
    constrain_symmetry=True, # whether to constrain the symmetry
)

relaxed_structure = relaxer.relax(structure, fmax=0.001, steps=500)
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 06:47:00      -10.912512        3.663198
# BFGS:    1 06:47:00      -11.506921        4.003321
# BFGS:    2 06:47:00      -13.788439        3.171815
# BFGS:    3 06:47:00      -14.625860        0.190155
# BFGS:    4 06:47:00      -14.628172        0.196123
# BFGS:    5 06:47:00      -14.184112        2.640507
# BFGS:    6 06:47:00      -14.634958        0.221206
# BFGS:    7 06:47:00      -14.641796        0.308700
# BFGS:    8 06:47:00      -14.385571        2.258987
# BFGS:    9 06:47:00      -14.655933        0.493703
# BFGS:   10 06:47:00      -14.665016        0.618666
# BFGS:   11 06:47:00      -14.667025        0.805115
# BFGS:   12 06:47:00      -14.683677        0.695268
# BFGS:   13 06:47:00      -14.692751        0.599783
# BFGS:   14 06:47:00      -14.707533        0.337897
# BFGS:   15 06:47:00      -14.714073        0.093146
# BFGS:   16 06:47:00      -14.714493        0.040548
# BFGS:   17 06:47:00      -14.714563        0.037339
# BFGS:   18 06:47:00      -14.714665        0.028500
# BFGS:   19 06:47:00      -14.714785        0.025582
# BFGS:   20 06:47:00      -14.714849        0.016375
# BFGS:   21 06:47:00      -14.714868        0.011818
# BFGS:   22 06:47:00      -14.714874        0.013813
# BFGS:   23 06:47:00      -14.714899        0.028920
# BFGS:   24 06:47:00      -14.715265        0.184158
# BFGS:   25 06:47:00      -14.692392        1.375371
# BFGS:   26 06:47:00      -14.717562        0.168822
# BFGS:   27 06:47:00      -14.719121        0.301549
# BFGS:   28 06:47:00      -14.720230        0.463828
# BFGS:   29 06:47:00      -14.721045        0.524888
# BFGS:   30 06:47:00      -14.631319        2.113770
# BFGS:   31 06:47:00      -14.725836        0.723091
# BFGS:   32 06:47:00      -14.730721        0.883747
# BFGS:   33 06:47:00      -14.659925        2.078683
# BFGS:   34 06:47:00      -14.746654        1.117225
# BFGS:   35 06:47:00      -14.751775        1.274092
# BFGS:   36 06:47:00      -14.756380        1.645872
# BFGS:   37 06:47:00      -14.759073        1.530592
# BFGS:   38 06:47:00      -14.759882        1.463286
# BFGS:   39 06:47:00      -14.760445        1.429471
# BFGS:   40 06:47:00      -14.762066        1.366813
# BFGS:   41 06:47:00      -14.764820        1.305413
# BFGS:   42 06:47:00      -14.769428        1.258418
# BFGS:   43 06:47:00      -14.774652        1.258410
# BFGS:   44 06:47:00      -14.778969        1.301304
# BFGS:   45 06:47:00      -14.783629        1.351302
# BFGS:   46 06:47:00      -14.794508        1.396286
# BFGS:   47 06:47:00      -14.818220        1.336039
# BFGS:   48 06:47:00      -14.863894        1.200064
# BFGS:   49 06:47:01      -14.920072        0.795599
# BFGS:   50 06:47:01      -14.941078        0.412313
# BFGS:   51 06:47:01      -14.948091        0.271236
# BFGS:   52 06:47:01      -14.951932        0.215575
# BFGS:   53 06:47:01      -14.954906        0.194152
# BFGS:   54 06:47:01      -14.958340        0.146618
# BFGS:   55 06:47:01      -14.961233        0.115630
# BFGS:   56 06:47:01      -14.962593        0.056840
# BFGS:   57 06:47:01      -14.962854        0.012588
# BFGS:   58 06:47:01      -14.962883        0.005840
# BFGS:   59 06:47:01      -14.962887        0.001544
# BFGS:   60 06:47:01      -14.962886        0.000257

# %%
structure.get_positions()
# Out:
# array([[ 7.21726083e-03, -1.35003840e-03,  1.60664652e-03],
#        [ 1.37044087e+00,  1.87825582e+00,  1.38471514e+00]])

# %%
print(f"Energy (eV)                 = {structure.get_potential_energy()}")
print(f"Energy per atom (eV/atom)   = {structure.get_potential_energy()/len(structure)}")
print(f"Forces of first atom (eV/A) = {structure.get_forces()[0]}")
print(f"Stress[0][0] (x-x) (eV/A^3) = {structure.get_stress(voigt=False)[0][0]}")
print(f"Stress[0][0] (x-x) (GPa)    = {structure.get_stress(voigt=False)[0][0] / GPa}")
# Out:
# Energy (eV)                 = -14.962885856628418
# Energy per atom (eV/atom)   = -7.481442928314209
# Forces of first atom (eV/A) = [1.819586e-05 4.854519e-07 6.585188e-06]
# Stress[0][0] (x-x) (eV/A^3) = 1.590344129916762e-05
# Stress[0][0] (x-x) (GPa)    = 0.0025480121839791536

# %%
_ = visualise_structure(structure)
# Out:
# Structure positions: [[ 7.21726083e-03 -1.35003840e-03  1.60664652e-03]
#  [ 1.37044087e+00  1.87825582e+00  1.38471514e+00]]
# <div id="3dmolviewer_173873802160318"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_173873802160318" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_173873802160318 = null;
# var warn = document.getElementById("3dmolwarning_173873802160318");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer